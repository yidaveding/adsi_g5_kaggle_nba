# %%
# import packages
import pandas as pd
import numpy as np

# set working directory
import os
os.chdir('/home/jovyan/work/')

# %%
from src.data.load_dataset import load_split_store
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

# load_split_store
X_train, y_train, X_val, y_val, X_test, y_test, test_data = load_split_store(
                                                                    filepath='data/', 
                                                                    scaler=scaler, 
                                                                    resample=False, 
                                                                    random_state=42, 
                                                                    test_size=0.1, 
                                                                    replace_negatives=False)

# %%
train_data = pd.read_csv("data/raw/train.csv")
train_data.drop(['Id_old', 'Id', 'MIN', 'FGM', 'FGA', 'FTM', 'FTA', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'TOV', 'TARGET_5Yrs'], axis=1).describe()
# Out:
#                 GP          PTS          FG%      3P Made          3PA  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean     62.777875     7.267088    44.608900     0.264525     0.816562
# std      17.118774     4.318732     6.155453     0.384093     1.060964
# min      -8.000000     0.800000    21.300000    -1.100000    -3.100000
# 25%      51.000000     4.100000    40.400000     0.000000     0.100000
# 50%      63.000000     6.300000    44.400000     0.300000     0.800000
# 75%      74.000000     9.500000    48.700000     0.500000     1.500000
# max     123.000000    34.200000    67.200000     1.700000     4.700000
#
#                3P%          FT%          BLK
# count  8000.000000  8000.000000  8000.000000
# mean     19.583700    71.365825     0.245212
# std      16.003155    10.430447     0.821037
# min     -38.500000   -13.300000   -17.900000
# 25%       8.400000    65.000000     0.100000
# 50%      19.500000    71.400000     0.200000
# ...

# %%
df = test_data[test_data<0]
df = df.dropna(thresh=1)
len(df) / len(test_data)
# Out:
# 0.3735193471966307

# %%
df = train_data[train_data<0]
df = df.dropna(thresh=1)
len(df) / len(train_data)
# Out:
# 0.38075

# %%
train_data.drop(['Id_old', 'Id'], axis=1).describe()
# Out:
#                 GP          MIN          PTS          FGM          FGA  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean     62.777875    18.576662     7.267088     2.807037     6.231212
# std      17.118774     8.935263     4.318732     1.693373     3.584559
# min      -8.000000     2.900000     0.800000     0.300000     0.800000
# 25%      51.000000    12.000000     4.100000     1.600000     3.600000
# 50%      63.000000    16.800000     6.300000     2.400000     5.400000
# 75%      74.000000    23.500000     9.500000     3.700000     8.100000
# max     123.000000    73.800000    34.200000    13.100000    28.900000
#
#                FG%      3P Made          3PA          3P%          FTM  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean     44.608900     0.264525     0.816562    19.583700     1.392525
# std       6.155453     0.384093     1.060964    16.003155     0.926153
# ...

# %%
test_data = pd.read_csv("data/raw/test.csv")
test_data.drop(['Id_old', 'Id', 'MIN', 'FGM', 'FGA', 'FTM', 'FTA', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'TOV'], axis=1).describe()
# Out:
#                 GP          PTS          FG%      3P Made          3PA  \
# count  3799.000000  3799.000000  3799.000000  3799.000000  3799.000000
# mean     62.853909     7.328034    44.599079     0.255962     0.796920
# std      17.151740     4.294724     6.040168     0.380987     1.052862
# min       6.000000     0.700000    25.100000    -1.000000    -2.700000
# 25%      51.000000     4.200000    40.500000     0.000000     0.100000
# 50%      63.000000     6.400000    44.600000     0.300000     0.800000
# 75%      74.000000     9.400000    48.500000     0.500000     1.500000
# max     126.000000    33.000000    74.600000     1.600000     4.300000
#
#                3P%          FT%          BLK
# count  3799.000000  3799.000000  3799.000000
# mean     19.234746    71.612924     0.257726
# std      15.968989    10.457336     0.639660
# min     -38.000000    23.700000    -7.100000
# 25%       8.500000    65.000000     0.100000
# 50%      19.400000    71.500000     0.200000
# ...

# %%
df = test_data[test_data['FT%']>100]
df.shape
# Out:
# (30, 21)

# %%
df = train_data.copy()
df['tREB'] = df['OREB'] + df['DREB']
dfx = df[df['tREB'] != df['REB']]
dfx.shape
# Out:
# (6161, 23)

# %%
6161/8000
# Out:
# 0.770125
